# %% [markdown]
# # MOVILES  -  EDA REFUERZO

# %% [markdown]
# 1. IMPORTACION DE LIBRERIAS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
pd.set_option('display.max_columns', None)

# %% [markdown]
# 2. LECTURA Y CARGA CONJUNTO DE DATOS

# %%
df = pd.read_csv('data/smartphonesmessy.csv')

# %% [markdown]
# 3. EXPLORACION INICIAL DATOS

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
df.shape
# Out:
# (1020, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.isna().sum()/len(df)*100
# Out:
# model         0.000000
# price         0.000000
# rating       13.823529
# sim           0.000000
# processor     0.000000
# ram           0.000000
# battery       0.000000
# display       0.000000
# camera        0.098039
# card          0.686275
# os            1.666667
# dtype: float64

# %%
df[df['model']=='Samsung Guru GT-E1215']
# Out:
#                      model   price  rating         sim        processor  \
# 699  Samsung Guru GT-E1215  ₹1,850     NaN  Single Sim  800 mAh Battery
#
#                                   ram         battery      display camera  \
# 699  1.5 inches, 120 x 120 px Display  No Rear Camera  No FM Radio    NaN
#
#     card   os
# 699  NaN  NaN

# %% [markdown]
# 4. TRATAMIENTO DE DATOS FALTANTES Y ANOMALIAS

# %%
# Se suprime la lera R con el que inicia cada valor de la variable 'price'
df['price']=df['price'].str[1:]
'''
Se convierte la variable 'price' a float (usando REGEX: realizando match con cualquier simbolo DIFERENTE a punto o digito) y se guarda 
en la nueva variable price_€
'''
df['price_€']= df['price'].replace('[^\d.]', '', regex=True).astype(float)
df
# Out:
#                                 model   price  rating  \
# 0                       OnePlus 11 5G  54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19,989    81.0
# 2               Samsung Galaxy A14 5G  16,499    75.0
# 3                Motorola Moto G62 5G  14,999    81.0
# 4                  Realme 10 Pro Plus  24,999    82.0
# ...                               ...     ...     ...
# 1015       Motorola Moto Edge S30 Pro  34,990    83.0
# 1016                      Honor X8 5G  14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28,990    85.0
# 1018             Motorola Moto G91 5G  19,990    80.0
# 1019           Samsung Galaxy M52s 5G  24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df['price_€'].describe()
# Out:
# count      1020.000000
# mean      31371.767647
# std       39168.942590
# min          99.000000
# 25%       12464.250000
# 50%       19815.000000
# 75%       34999.000000
# max      650000.000000
# Name: price_€, dtype: float64

# %%
# Suprimimos la variable 'price'

df.drop(['price'], axis=1, inplace=True)

# %%
# Realizamos la conversion de Rupias a Euros multiplicando la variable 'price_€' por 0.11 (factor conversor al dia de hoy)

df['price_€']=df['price_€']*0.011
df
# Out:
#                                 model   price  rating  \
# 0                       OnePlus 11 5G  54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19,989    81.0
# 2               Samsung Galaxy A14 5G  16,499    75.0
# 3                Motorola Moto G62 5G  14,999    81.0
# 4                  Realme 10 Pro Plus  24,999    82.0
# ...                               ...     ...     ...
# 1015       Motorola Moto Edge S30 Pro  34,990    83.0
# 1016                      Honor X8 5G  14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28,990    85.0
# 1018             Motorola Moto G91 5G  19,990    80.0
# 1019           Samsung Galaxy M52s 5G  24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
# Guardamos los cambios en el nuevo achivo llamado moviles.csv  
df.to_csv('moviles.csv', index=False)

# %%
df1 = pd.read_csv('moviles.csv')
df1.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
# Por medio de esta linea de codigo, ayudados de REGEX, extraemos en la columna 'sim_num' la cantidad de tarjetas sim que el movil soporta
df1['sim_num'] = df1['sim'].str.extract(r'^(\w+\s*\w+)', expand=True)
df1
# Out:
#                                 model  rating  \
# 0                       OnePlus 11 5G    89.0
# 1           OnePlus Nord CE 2 Lite 5G    81.0
# 2               Samsung Galaxy A14 5G    75.0
# 3                Motorola Moto G62 5G    81.0
# 4                  Realme 10 Pro Plus    82.0
# ...                               ...     ...
# 1015       Motorola Moto Edge S30 Pro    83.0
# 1016                      Honor X8 5G    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)    85.0
# 1018             Motorola Moto G91 5G    80.0
# 1019           Samsung Galaxy M52s 5G    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# ...

# %%
# creamos tres columnas con cada una de las Generaciones, como nos devuelve un Boleano, lo cambiamos a un dato numerico
df1['sim_3G'] = df1['sim'].str.contains(r'\b3G\b')
df1['sim_3G'] = df1['sim_3G'].map({True: 1, False: 0})

df1['sim_4G'] = df1['sim'].str.contains(r'\b4G\b')
df1['sim_4G'] = df1['sim_4G'].map({True: 1, False: 0})

df1['sim_5G'] = df1['sim'].str.contains(r'\b5G\b')
df1['sim_5G'] = df1['sim_5G'].map({True: 1, False: 0})



df1
# Out:
#                                 model  rating  \
# 0                       OnePlus 11 5G    89.0
# 1           OnePlus Nord CE 2 Lite 5G    81.0
# 2               Samsung Galaxy A14 5G    75.0
# 3                Motorola Moto G62 5G    81.0
# 4                  Realme 10 Pro Plus    82.0
# ...                               ...     ...
# 1015       Motorola Moto Edge S30 Pro    83.0
# 1016                      Honor X8 5G    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)    85.0
# 1018             Motorola Moto G91 5G    80.0
# 1019           Samsung Galaxy M52s 5G    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# ...

# %%
"""
cardi = pd.DataFrame(columns =['cardinalidad', 'porc_cardi', 'tipo_dato', 'val_unicos', 'tipo_variable'], index= df.columns)
cardi['cardinalidad'] = [df[col].nunique() for col in df.columns]
cardi['porc_cardi'] = cardi['cardinalidad']/len(df)*100
cardi['tipo_dato'] = df.dtypes
cardi['val_unicos'] = [df[col].nunique() if df[col].nunique()<=15 else 'VNR' for col in df.columns]
cardi
"""
# Out:
# "\ncardi = pd.DataFrame(columns =['cardinalidad', 'porc_cardi', 'tipo_dato', 'val_unicos', 'tipo_variable'], index= df.columns)\ncardi['cardinalidad'] = [df[col].nunique() for col in df.columns]\ncardi['porc_cardi'] = cardi['cardinalidad']/len(df)*100\ncardi['tipo_dato'] = df.dtypes\ncardi['val_unicos'] = [df[col].nunique() if df[col].nunique()<=15 else 'VNR' for col in df.columns]\ncardi\n"
